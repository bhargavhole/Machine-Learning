# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("/content/drive/MyDrive/ML and deepL/linear regression1/homeprices.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  560000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(df.area, df.price, color='red', marker='+')

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
reg.predict(pd.DataFrame([3300], columns = ['area']))
# Out:
# array([627739.7260274])

# %%
d = pd.read_csv("/content/drive/MyDrive/ML and deepL/linear regression1/areas.csv")
d.head(3)
# Out:
#    area
# 0  1000
# 1  1200
# 2   892

# %% [markdown]
# Prices of area in file

# %%
p = reg.predict(d)

# %% [markdown]
# Adding the prices in the original file with new column and displaying it

# %%
d['Price'] = p
d
# Out:
#    area         Price
# 0  1000  3.126712e+05
# 1  1200  3.400685e+05
# 2   892  2.978767e+05
# 3  1330  3.578767e+05
# 4  1234  3.447260e+05
# 5  4568  8.014384e+05
# 6  9000  1.408562e+06

# %%
d.to_csv("/content/drive/MyDrive/ML and deepL/linear regression1/prediction.csv", index=False)

# %%
# %matplotlib inline
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(df.area, df.price, color='red', marker='+')
plt.plot(df.area,reg.predict(df[['area']]),color='blue')
